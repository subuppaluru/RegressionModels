# %% [markdown]
# #Types of regression
#
# ##Linear Regression
#
# ##Logistic Regression
#
# ##Polynomial Regression
#
# #Regularized Regression Models
#
# ##Ridge Regression
#
# ##Lasso Regression
#
# ##ElasticNet Regression
